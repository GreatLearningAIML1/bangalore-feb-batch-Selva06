# %% [markdown]
# ## Lists, Dictionaries and Sets in Python

# %% [markdown]
# ## Part 1
#
# ### Lists in Python
#
# Sequences in Python are data structures that hold objects in an ordered array. Now, we will work on Lists, the most common sequence data types in Python.

# %%
#Example 
l1 = ['learning', "Python", 'is fun?', True]
print(l1)
# Out:
# ['learning', 'Python', 'is fun?', True]

# %% [markdown]
# List can also be created by using list() function.

# %%
#Example
l2 = list(("learning", "for", "life", True))
print(l2)
# Out:
# ['learning', 'for', 'life', True]

# %% [markdown]
# Adding to an existing list
#
# ### Question 1
#
# Add 10 to list l1 given above.
#
# [ **Hint: ** Use **append** ]

# %%
l1 = ['learning', "Python", 'is fun?', True]
type(l1)
l1.append('10')
print("updated list:",l1)
# Out:
# updated list: ['learning', 'Python', 'is fun?', True, '10']

# %% [markdown]
# Removing from an existing list
#
# ### Question 2
#
# Remove 10 from l1.
#
# [ **Hint:** Use **remove**]

# %%
print("removing 10:",l1.remove('10'))
l1
# Out:
# removing 10: None
# ['learning', 'Python', 'is fun?', True]

# %% [markdown]
# Joining 2 lists
#
# ### Question 3
#
# [ **Hint: ** Use **+** operator or **extend**]

# %%
l1 = ['learning', "Python", 'is fun?', True]
l2 = list(("learning", "for", "life", True))

# %%
merge=l1+l2
merge
# Out:
# ['learning', 'Python', 'is fun?', True, 'learning', 'for', 'life', True]

# %% [markdown]
# Number List
#
# ### Question 4
#
# Find Range and Mean of l3.
#
# l3 = [2,4,6,8]
#
# [ **Hint: ** Use **len(),sum(), min(), max()** functions ]
#
# If you want to use standard functions like mean & range, you have to import them from numpy else you can calculate them the traditional way using formulas

# %%
import numpy as np
l3 = [2,4,6,8]
print("Minimum:",min(l3))
print("Maximum:",max(l3))

print("range:",max(l3)-min(l3))
print("mean:",np.mean(l3))
# Out:
# Minimum: 2
# Maximum: 8
# range: 6
# mean: 5.0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-304-a81afd6eaf9d> in <module>
# ----> 1 l3.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %% [markdown]
# Count the occurances of an element in a given list.
#
# ### Question 5
# Append the given sequence of numbers to l3 (given above) 0,1,3,3,5,5,7,9. Count the occurences of 5 in l3.
#
# [ **Hint: ** Use ** + operator to add multiple elements in the array and count() function to print the occurences**]

# %%
l3 = [2,4,6,8]
new_list=[0,1,3,3,5,5,7,9]
l3 = l3 + new_list
print("newlist",l3)
print("occurences",l3.count(5))
# Out:
# newlist [2, 4, 6, 8, 0, 1, 3, 3, 5, 5, 7, 9]
# occurences 2

# %% [markdown]
# Sorting and Reversing a list
#
# ### Question 6
# sort and print l3 in ascending and descending order sequentially (given above)
#
# **(Hint: Use .sort() function)**

# %%
l3.sort()
print("ascending",l3)
l3.sort(reverse = True)
print("descending",l3)
# Out:
# ascending [0, 1, 2, 3, 3, 4, 5, 5, 6, 7, 8, 9]
# descending [9, 8, 7, 6, 5, 5, 4, 3, 3, 2, 1, 0]

# %% [markdown]
# ### Functions

# %% [markdown]
# **Example:**
#
# **def** function_name(args)**:**
#
#     function code goes here

# %% [markdown]
# ### Question 7
#
# Define a function with name **sum_3** which can take 3 numbers as input, and returns sum of them.

# %%
def sum_3():
    print ("Please enter three numbers:")
    a = input()
    b = input()
    c = input()
    return sum((a,b,c))

print sum_3()
# Out:
#   File "<ipython-input-103-2edbfa30947c>", line 8
#     print sum_3()
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Lambda Functions

# %% [markdown]
# Anonymous functions or no name functions, which can be considered when you use a function only once.
#
# **Example:**
#
# f = lambda x, y : x + y
#
# f(1,1)
#
# 2

# %% [markdown]
# ### Question 8
#
# Write the same above **sum_3** function using lambda.

# %% [markdown]
# # Numpy

# %% [markdown]
# We have seen python basic data structures in our last section. They are great but lack specialized features for data analysis. Like, adding roows, columns, operating on 2d matrices aren't readily available. So, we will use *numpy* for such functions.

# %%
import numpy as np

# %% [markdown]
# Numpy operates on *nd* arrays. These are similar to lists but contains homogenous elements but easier to store 2-d data.

# %%
l1 = [1,2,3,4]
nd1 = np.array(l1)
print(nd1)

l2 = [5,6,7,8]
nd2 = np.array([l1,l2])
print(nd2)
# Out:
# [1 2 3 4]
# [[1 2 3 4]
#  [5 6 7 8]]

# %% [markdown]
# Sum functions on np.array()

# %%
print(nd2.shape)

print(nd2.size)

print(nd2.dtype)
# Out:
# (2, 4)
# 8
# int32

# %% [markdown]
# ### Question 1
#
# Create an identity 2d-array or matrix (with ones across the diagonal).
#
# [ **Hint: ** You can also use **np.identity()** function ]

# %%
a = np.identity(3) 
print("\nMatrix a : \n", a)
# Out:
# Matrix a :
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# ### Question 2
#
# Create a 2d-array or matrix of order 3x3 with values = 9,8,7,6,5,4,3,2,1 arranged in the same order.
#
# Use: **np.matrix()** function

# %%
b = np.matrix([[9,8,7],[6,5,4], [3,2,1]]) 
print("\n", b)
# Out:
#  [[9 8 7]
#  [6 5 4]
#  [3 2 1]]

# %% [markdown]
# ### Question 3
#
# Reverse both the rows and columns of the given matrix.
#
# Hint: You can use the transpose **.T**)

# %%
b.T
#print(np.transpose(b))
# Out:
# matrix([[9, 6, 3],
#         [8, 5, 2],
#         [7, 4, 1]])

# %% [markdown]
# ### Question 4
# Add + 1 to all the elements in the given matrix.

# %%
b
# Out:
# matrix([[9, 8, 7],
#         [6, 5, 4],
#         [3, 2, 1]])

# %%
b=b+1
b
# Out:
# matrix([[12, 11, 10],
#         [ 9,  8,  7],
#         [ 6,  5,  4]])

# %% [markdown]
# Similarly you can do operations like scalar  substraction, division, multiplication (operating on each element in the matrix)

# %% [markdown]
# ### Question 5
#
# Find the mean of all elements in the given matrix nd6.
# nd6 = [[  1   4   9 121 144 169]
#  [ 16  25  36 196 225 256]
#  [ 49  64  81 289 324 361]]
#
#  Use: **.mean()** function

# %%
x = np.array([[1,4,9,121,144,169], [16,25,36,196,225,256],[49,64,81,289,324,361]], np.int32)
np.mean(x)
# Out:
# 131.66666666666666

# %% [markdown]
# ### Question 7
#
# Find the dot product of two given matrices.
#
# [**Hint:** Use **np.dot()**]

# %%
print(a)
print(b)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[12 11 10]
#  [ 9  8  7]
#  [ 6  5  4]]

# %%
np.dot(a,b)
# Out:
# matrix([[12., 11., 10.],
#         [ 9.,  8.,  7.],
#         [ 6.,  5.,  4.]])

# %% [markdown]
# # Pandas

# %% [markdown]
# We have seen Numpy in the last section. It is good at performing math operation on 2d-arrays of numbers. But the major drawback is, it cannot deal with heterogenous values. So, Pandas dataframes are helpful in that aspect for storing different data types and referring the values like a dict in python instead of just referring each item with index.
#
# [Link to Official Documentation](http://pandas.pydata.org/pandas-docs/version/0.23/dsintro.html)

# %% [markdown]
# ## Series

# %% [markdown]
# Pandas series are almost same as nd arrays in numpy, with a additional inferencing ability with custom labels like *keys* in a *dictionary* in python.

# %%
import numpy as np
import pandas as pd

# %%
#Example

series1 = pd.Series(data = [1,2,3], index = ['key1', 'key2', 'key3'])
series1
# Out:
# key1    1
# key2    2
# key3    3
# dtype: int64

# %% [markdown]
# ### Question 1
#
# Convert a given dict to pd series.
#
# [**Hint:** Use **.Series**]

# %%
d1 = {'a': 1, 'b': 2, 'c': 3}
s = pd.Series(d1)
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
series1
# Out:
# key1    1
# key2    2
# key3    3
# dtype: int64

# %% [markdown]
# You can directly use numpy functions on series.
# ### Question 2
#
# Find the dot product of both the series create above
#
#
# [ **Hint: ** Use **np.dot()** ]

# %%
new_dp=np.dot(series1,s)
type(new_dp)
new_dp
# Out:
# 14

# %% [markdown]
# ## Dataframes

# %% [markdown]
# A dataframe is a table with labeled columns which can hold different types of data in each column.

# %%
# Example
d1 = {'a': [1,2,3], 'b': [3,4,5], 'c':[6,7,8] }
df1 = pd.DataFrame(d1)
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %% [markdown]
# ### Question 3
#
# Select second row in the above dataframe df1.

# %%
df1[2:3]
df1.loc[1:1,]
# Out:
#    a  b  c
# 1  2  4  7

# %% [markdown]
# ### Question 4
#
# Select column c in second row of df1.
#
# [ **Hint: ** For using labels use **df.loc[row, column]**. For using numeric indexed use **df.iloc[]**. For using mixture of numeric indexes and labels use **df.ix[row, column]** ]

# %%
df1.ix[1,"c"]
# Out:
# C:\Users\selvm\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 7

# %% [markdown]
# ## Using Dataframes on a dataset

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %%
## Reading a dataset from a csv file using pandas.
mtcars = pd.read_csv('mtcars.csv')
mtcars.index = mtcars['name']
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Following questions are based on analysing a particular dataset using dataframes.

# %% [markdown]
# ### Question 5
#
# Check the type and dimensions of given dataset - mtcars.
#
#
# [ **Hint: ** Use **type()** and **df.shape** ]

# %%
type(mtcars)
mtcars.shape
# Out:
# (32, 12)

# %% [markdown]
# ### Question 6
#
# Check the first 10 lines and last 10 lines of the given dataset- mtcars.
#
# [**Hint:** Use **.head()** and **.tail()**]

# %%
mtcars.head(10)
mtcars.tail(10)
# Out:
#                               name   mpg  cyl   disp   hp  drat     wt   qsec  \
# name
# AMC Javelin            AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30
# Camaro Z28              Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41
# Pontiac Firebird  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05
# Fiat X1-9                Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90
# Porsche 914-2        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70
# Lotus Europa          Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90
# Ford Pantera L      Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50
# Ferrari Dino          Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50
# Maserati Bora        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60
# Volvo 142E              Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60
#
#                   vs  am  gear  carb
# name
# AMC Javelin        0   0     3     2
# Camaro Z28         0   0     3     4
# Pontiac Firebird   0   0     3     2
# Fiat X1-9          1   1     4     1
# Porsche 914-2      0   1     5     2
# Lotus Europa       1   1     5     2
# Ford Pantera L     0   1     5     4
# Ferrari Dino       0   1     5     6
# Maserati Bora      0   1     5     8
# Volvo 142E         1   1     4     2

# %% [markdown]
# ### Question 7
#
# Print all the column labels in the given dataset - mtcars.
#
# [ **Hint: ** Use **df.columns** ]

# %%
mtcars.columns
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %% [markdown]
# ### Question 8

# %% [markdown]
# Select first 6 rows and 3 columns in mtcars dataframe.
#
# **Hint: **
# mtcars.ix[:,:] gives all rows and columns in the dataset.

# %%
mtcars.iloc[:6,:3]
# Out:
#                                 name   mpg  cyl
# name
# Mazda RX4                  Mazda RX4  21.0    6
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6
# Datsun 710                Datsun 710  22.8    4
# Hornet 4 Drive        Hornet 4 Drive  21.4    6
# Hornet Sportabout  Hornet Sportabout  18.7    8
# Valiant                      Valiant  18.1    6

# %% [markdown]
# ## Lab Brief - Statistical Learning with Python

# %% [markdown]
# ### Part-1

# %% [markdown]
# ## Measures of Data

# %% [markdown]
# Descriptive Statistcs are measures that summarize important features of data. Producing these descriptive statistics is a common first step to take after cleaning and preparing a dataset for further analysis. Examples are like calculating Mean or Median. In this lab, we will be looking into some of these functions and explore several new ones.

# %% [markdown]
# #### Measures of Central Tendency

# %% [markdown]
# Whenever you measure things of the same kind, a fairly large number of such measurements will tend to cluster around the middle value. Such a value is called a measure of "Central Tendency". The other terms that are used synonymously are "Measures of Location", or "Statistical Averages".

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

mtcars = pd.read_csv('mtcars.csv')

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %% [markdown]
# #### Explore the data - Setting the index

# %%
mtcars.index = mtcars["name"]
mtcars.head()
# mtcars.mean() #By default this will give the mean of each column
# Out:
#                                 name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# name
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %% [markdown]
# ### Question 1
#
# What is the first car name given in mtcars?
#
# ** Make use of index which has been set previously **
#
# **Hint**: Use .loc function

# %%
mtcars.loc[:,["name"]].head(1)
# Out:
#                 name
# name
# Mazda RX4  Mazda RX4

# %% [markdown]
# ### Question 2
# What is the highest difference between the hp and cyl?
#
# **Hint:** You can use **max()** function to find the difference

# %%
mtcars.max(["hp"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-4e3b27df1e60> in <module>
# ----> 1 mtcars.max(["hp"])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    9611                                       skipna=skipna)
#    9612         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9613                             numeric_only=numeric_only)
#    9614
#    9615     return set_function_name(stat_func, name, cls)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6850         else:
#    6851             # TODO: Make other agg func handle axis=None properly
# -> 6852             axis = self._get_axis_number(axis)
#    6853             labels = self._get_agg_axis(axis)
#    6854             constructor = self._constructor
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     363
#     364     def _get_axis_number(self, axis):
# --> 365         axis = self._AXIS_ALIASES.get(axis, axis)
#     366         if is_integer(axis):
#     367             if axis in self._AXIS_NAMES:
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Question 3
# What are the cars having highest weight(wt) and lowest weight(wt)?
#
# **Hint:** Use idxmax() and idxmin() to locate the row
#
# Use **.iloc** function to print the  row
#
# **Note:** Both idxmax and idxmin belong to pandas

# %%
s=mtcars.loc[mtcars['wt'].idxmax()]
s1=mtcars.loc[mtcars['wt'].idxmin()]

#print(s1)
print("max weight",s.iloc[6])
print("min weight",s1.iloc[6])
# Out:
# max weight 5.4239999999999995
# min weight 1.5130000000000001

# %% [markdown]
# ### Question 4
#
# Find the mean of each row and each column in the given dataset.
#
# **Hint:** Use .mean() function. To operate on rows use **axis=0**, on columns use **axis=1**

# %%
print(mtcars.mean())
print("-------------------------------------------")
print(mtcars.mean(axis=1))
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# -------------------------------------------
# name
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# Toyota Corolla         18.814091
# Toyota Corona          24.888636
# Dodge Challenger       47.240909
# AMC Javelin            46.007727
# Camaro Z28             58.752727
# Pontiac Firebird       57.379545
# Fiat X1-9              18.928636
# Porsche 914-2          24.779091
# Lotus Europa           24.880273
# Ford Pantera L         60.971818
# Ferrari Dino           34.508182
# Maserati Bora          63.155455
# Volvo 142E             26.262727
# dtype: float64

# %% [markdown]
# ### Question 5
#
# Plot mpg values of mtcards dataframe using matplotlib.
#
# **Hint: Use plt.plot function**

# %%
import matplotlib.pyplot as plt
type(mtcars)
mtcars.columns
mtcars.mpg.plot.hist()

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# Measures of Dispersion (Spread) are statistics that describe how data varies. Measure of dispersion gives us the sense of how much the data tends to diverge from the central tendency.

# %% [markdown]
# ### Question 6
#
# What the range of `mpg` in the given dataset?
#
# **Hint:** Range = max-min

# %%
mtcars.groupby(["mpg"]).agg(["min","max"])
#df.groupby(["START_DATE*"]).agg(["min","max"])
# Out:
#                     name                      cyl       disp          hp       \
#                      min                  max min max    min    max  min  max
# mpg
# 10.4  Cadillac Fleetwood  Lincoln Continental   8   8  460.0  472.0  205  215
# 13.3          Camaro Z28           Camaro Z28   8   8  350.0  350.0  245  245
# 14.3          Duster 360           Duster 360   8   8  360.0  360.0  245  245
# 14.7   Chrysler Imperial    Chrysler Imperial   8   8  440.0  440.0  230  230
# 15.0       Maserati Bora        Maserati Bora   8   8  301.0  301.0  335  335
# 15.2         AMC Javelin          Merc 450SLC   8   8  275.8  304.0  150  180
# 15.5    Dodge Challenger     Dodge Challenger   8   8  318.0  318.0  150  150
# 15.8      Ford Pantera L       Ford Pantera L   8   8  351.0  351.0  264  264
# 16.4          Merc 450SE           Merc 450SE   8   8  275.8  275.8  180  180
# 17.3          Merc 450SL           Merc 450SL   8   8  275.8  275.8  180  180
# 17.8           Merc 280C            Merc 280C   6   6  167.6  167.6  123  123
# 18.1             Valiant              Valiant   6   6  225.0  225.0  105  105
# 18.7   Hornet Sportabout    Hornet Sportabout   8   8  360.0  360.0  175  175
# 19.2            Merc 280     Pontiac Firebird   6   8  167.6  400.0  123  175
# 19.7        Ferrari Dino         Ferrari Dino   6   6  145.0  145.0  175  175
# 21.0           Mazda RX4        Mazda RX4 Wag   6   6  160.0  160.0  110  110
# 21.4      Hornet 4 Drive           Volvo 142E   4   6  121.0  258.0  109  110
# 21.5       Toyota Corona        Toyota Corona   4   4  120.1  120.1   97   97
# 22.8          Datsun 710             Merc 230   4   4  108.0  140.8   93   95
# 24.4           Merc 240D            Merc 240D   4   4  146.7  146.7   62   62
# 26.0       Porsche 914-2        Porsche 914-2   4   4  120.3  120.3   91   91
# 27.3           Fiat X1-9            Fiat X1-9   4   4   79.0   79.0   66   66
# 30.4         Honda Civic         Lotus Europa   4   4   75.7   95.1   52  113
# 32.4            Fiat 128             Fiat 128   4   4   78.7   78.7   66   66
# 33.9      Toyota Corolla       Toyota Corolla   4   4   71.1   71.1   65   65
#
#       drat       ...   qsec         vs      am     gear     carb
#        min   max ...    min    max min max min max  min max  min max
# mpg              ...
# 10.4  2.93  3.00 ...  17.82  17.98   0   0   0   0    3   3    4   4
# 13.3  3.73  3.73 ...  15.41  15.41   0   0   0   0    3   3    4   4
# 14.3  3.21  3.21 ...  15.84  15.84   0   0   0   0    3   3    4   4
# 14.7  3.23  3.23 ...  17.42  17.42   0   0   0   0    3   3    4   4
# 15.0  3.54  3.54 ...  14.60  14.60   0   0   1   1    5   5    8   8
# 15.2  3.07  3.15 ...  17.30  18.00   0   0   0   0    3   3    2   3
# 15.5  2.76  2.76 ...  16.87  16.87   0   0   0   0    3   3    2   2
# 15.8  4.22  4.22 ...  14.50  14.50   0   0   1   1    5   5    4   4
# 16.4  3.07  3.07 ...  17.40  17.40   0   0   0   0    3   3    3   3
# 17.3  3.07  3.07 ...  17.60  17.60   0   0   0   0    3   3    3   3
# 17.8  3.92  3.92 ...  18.90  18.90   1   1   0   0    4   4    4   4
# 18.1  2.76  2.76 ...  20.22  20.22   1   1   0   0    3   3    1   1
# 18.7  3.15  3.15 ...  17.02  17.02   0   0   0   0    3   3    2   2
# 19.2  3.08  3.92 ...  17.05  18.30   0   1   0   0    3   4    2   4
# 19.7  3.62  3.62 ...  15.50  15.50   0   0   1   1    5   5    6   6
# 21.0  3.90  3.90 ...  16.46  17.02   0   0   1   1    4   4    4   4
# 21.4  3.08  4.11 ...  18.60  19.44   1   1   0   1    3   4    1   2
# 21.5  3.70  3.70 ...  20.01  20.01   1   1   0   0    3   3    1   1
# 22.8  3.85  3.92 ...  18.61  22.90   1   1   0   1    4   4    1   2
# 24.4  3.69  3.69 ...  20.00  20.00   1   1   0   0    4   4    2   2
# 26.0  4.43  4.43 ...  16.70  16.70   0   0   1   1    5   5    2   2
# 27.3  4.08  4.08 ...  18.90  18.90   1   1   1   1    4   4    1   1
# 30.4  3.77  4.93 ...  16.90  18.52   1   1   1   1    4   5    2   2
# 32.4  4.08  4.08 ...  19.47  19.47   1   1   1   1    4   4    1   1
# 33.9  4.22  4.22 ...  19.90  19.90   1   1   1   1    4   4    1   1
#
# [25 rows x 22 columns]

# %% [markdown]
# ### Question 7
#
# Calculate the 25th quantile (lower quantile)for `mpg` in the given dataset.
#
# **Hint:** Use **.quantile()**

# %%
mtcars["mpg"].quantile([0.25,0.50,0.99])
# Out:
# 0.25    15.425
# 0.50    19.200
# 0.99    33.435
# Name: mpg, dtype: float64

# %% [markdown]
# ### Question 8
#
# Calculate the Inter-Quartile Range(IQR) for `mpg` in the given dataset.

# %% [markdown]
# Interquartile range (IQR) is another common measure of spread. IQR is the distance between the 3rd quartile and the 1st quartile.
#
# **Hint:** IQR = Q3 - Q1

# %%
Q1 = mtcars['mpg'].quantile(0.25)
Q3 = mtcars['mpg'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 7.375

# %% [markdown]
# ### Question 9
#
# Calculate the Variance, Standard Deviation and Median Absolute Deviation for `mpg`.

# %% [markdown]
# Variance and Standard Deviation are two other common measure of dispersion.
#
# **Hint:** Use .var() and .std()

# %% [markdown]
# **Hint:** Median Absolute Deviation - alternative measure of spread based on the median. It is the median of the absolute value of the deviations from the median.

# %%
mtcars.describe(include="all")
# Out:
#            name        mpg        cyl        disp          hp       drat  \
# count        32  32.000000  32.000000   32.000000   32.000000  32.000000
# unique       32        NaN        NaN         NaN         NaN        NaN
# top     Valiant        NaN        NaN         NaN         NaN        NaN
# freq          1        NaN        NaN         NaN         NaN        NaN
# mean        NaN  20.090625   6.187500  230.721875  146.687500   3.596563
# std         NaN   6.026948   1.785922  123.938694   68.562868   0.534679
# min         NaN  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%         NaN  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%         NaN  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%         NaN  22.800000   8.000000  326.000000  180.000000   3.920000
# max         NaN  33.900000   8.000000  472.000000  335.000000   4.930000
#
#                wt       qsec         vs         am       gear     carb
# count   32.000000  32.000000  32.000000  32.000000  32.000000  32.0000
# unique        NaN        NaN        NaN        NaN        NaN      NaN
# top           NaN        NaN        NaN        NaN        NaN      NaN
# freq          NaN        NaN        NaN        NaN        NaN      NaN
# mean     3.217250  17.848750   0.437500   0.406250   3.687500   2.8125
# std      0.978457   1.786943   0.504016   0.498991   0.737804   1.6152
# min      1.513000  14.500000   0.000000   0.000000   3.000000   1.0000
# 25%      2.581250  16.892500   0.000000   0.000000   3.000000   2.0000
# 50%      3.325000  17.710000   0.000000   0.000000   4.000000   2.0000
# 75%      3.610000  18.900000   1.000000   1.000000   4.000000   4.0000
# max      5.424000  22.900000   1.000000   1.000000   5.000000   8.0000
